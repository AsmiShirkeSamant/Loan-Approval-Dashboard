# %% [markdown]
# # Loan Approval Dashboard

# %% [markdown]
# using the basis of an US loan approval dataset from Kaggle, synthetic dataset has been generated with the following attributes:
#  0   person_age
#  1   person_gender
#  2   person_education
#  3   person_state
#  4   person_income
#  5   person_emp_status
#  6   person_emp_exp
#  7   person_home_ownership
#  8   has_help_debt
#  9   help_debt_amount
#  10  loan_amnt
#  11  loan_intent
#  12  loan_term_months
#  13  loan_int_rate
#  14  loan_percent_income
#  15  cb_person_cred_hist_length
#  16  credit_score
#  17  previous_loan_defaults_on_file
#  18  loan_status
#  19  application_date

# %%
import os
import pandas as pd
import numpy as np
#from dotenv import load_dotenv
import functools, operator

# %%
# %pip install seaborn

# %%
# %pip install matplotlib

# %%
data = pd.read_csv('au_loan_data.csv')
data
# Out:
#        person_age person_gender     person_education person_state  \
# 0              50        Female            Doctorate           WA
# 1              41          Male  Certificate/Diploma          VIC
# 2              40          Male         Postgraduate           SA
# 3              40        Female             Bachelor           WA
# 4              71        Female             Bachelor          VIC
# ...           ...           ...                  ...          ...
# 44995          39          Male             Bachelor          NSW
# 44996          75        Female  Certificate/Diploma          QLD
# 44997          32          Male          High School          NSW
# 44998          49          Male  Certificate/Diploma          NSW
# 44999          39        Female  Certificate/Diploma          NSW
#
#        person_income person_emp_status  person_emp_exp person_home_ownership  \
# 0              53716        Unemployed               4                  RENT
# 1              20000         Full-time               9                  RENT
# 2              34133            Casual               8              MORTGAGE
# 3              71808         Full-time               2                   OWN
# 4              36560         Full-time              10                  RENT
# ...              ...               ...             ...                   ...
# 44995          79355         Part-time               9              MORTGAGE
# 44996          41076         Full-time               7                   OWN
# 44997          40313         Part-time               4                FAMILY
# 44998          28757         Part-time               7                   OWN
# 44999         187195         Part-time               3                   OWN
#
#        has_help_debt  help_debt_amount  loan_amnt         loan_intent  \
# 0                  0                 0      13300    HOME_IMPROVEMENT
# 1                  0                 0      30200  DEBT_CONSOLIDATION
# 2                  0                 0      22200            PERSONAL
# 3                  1             19626      15800  DEBT_CONSOLIDATION
# 4                  0                 0      10600  DEBT_CONSOLIDATION
# ...              ...               ...        ...                 ...
# 44995              1             23714      32700             VEHICLE
# 44996              0                 0      13300  DEBT_CONSOLIDATION
# 44997              0                 0      10200    HOME_IMPROVEMENT
# 44998              0                 0      14300             VEHICLE
# 44999              0                 0      73300             VEHICLE
#
#        loan_term_months  loan_int_rate  loan_percent_income  \
# 0                    60          17.32               0.2476
# 1                    36          11.59               1.5100
# 2                    36          17.32               0.6504
# 3                    60          10.51               0.2200
# 4                    36          17.24               0.2899
# ...                 ...            ...                  ...
# 44995                60          14.75               0.4121
# 44996                12          17.93               0.3238
# 44997                72          14.45               0.2530
# 44998                36          16.68               0.4973
# 44999                60          11.54               0.3916
#
#        cb_person_cred_hist_length  credit_score  \
# 0                              32           713
# 1                              22           845
# 2                              20           755
# 3                              18           752
# 4                              51           655
# ...                           ...           ...
# 44995                          18           814
# 44996                          55           688
# 44997                          12           905
# 44998                          30           658
# 44999                          18           629
#
#       previous_loan_defaults_on_file  loan_status application_date
# 0                                 No            0       2023-06-15
# 1                                 No            0       2025-12-26
# 2                                 No            0       2024-11-01
# 3                                 No            0       2022-08-05
# 4                                 No            0       2024-03-31
# ...                              ...          ...              ...
# 44995                             No            0       2023-02-04
# 44996                            Yes            0       2023-10-01
# 44997                             No            0       2024-08-17
# 44998                             No            0       2022-12-13
# 44999                             No            0       2024-11-13
#
# [45000 rows x 20 columns]

# %% [markdown]
# ### Dataset overview:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   person_age                      45000 non-null  int64
#  1   person_gender                   45000 non-null  object
#  2   person_education                45000 non-null  object
#  3   person_state                    45000 non-null  object
#  4   person_income                   45000 non-null  int64
#  5   person_emp_status               45000 non-null  object
#  6   person_emp_exp                  45000 non-null  int64
#  7   person_home_ownership           45000 non-null  object
#  8   has_help_debt                   45000 non-null  int64
#  9   help_debt_amount                45000 non-null  int64
#  10  loan_amnt                       45000 non-null  int64
#  11  loan_intent                     45000 non-null  object
#  12  loan_term_months                45000 non-null  int64
#  13  loan_int_rate                   45000 non-null  float64
#  14  loan_percent_income             45000 non-null  float64
#  15  cb_person_cred_hist_length      45000 non-null  int64
#  16  credit_score                    45000 non-null  int64
#  17  previous_loan_defaults_on_file  45000 non-null  object
#  18  loan_status                     45000 non-null  int64
#  19  application_date                45000 non-null  object
# dtypes: float64(2), int64(10), object(8)
# memory usage: 5.5+ MB

# %%
data.head()
# Out:
#    person_age person_gender     person_education person_state  person_income  \
# 0          50        Female            Doctorate           WA          53716
# 1          41          Male  Certificate/Diploma          VIC          20000
# 2          40          Male         Postgraduate           SA          34133
# 3          40        Female             Bachelor           WA          71808
# 4          71        Female             Bachelor          VIC          36560
#
#   person_emp_status  person_emp_exp person_home_ownership  has_help_debt  \
# 0        Unemployed               4                  RENT              0
# 1         Full-time               9                  RENT              0
# 2            Casual               8              MORTGAGE              0
# 3         Full-time               2                   OWN              1
# 4         Full-time              10                  RENT              0
#
#    help_debt_amount  loan_amnt         loan_intent  loan_term_months  \
# 0                 0      13300    HOME_IMPROVEMENT                60
# 1                 0      30200  DEBT_CONSOLIDATION                36
# 2                 0      22200            PERSONAL                36
# 3             19626      15800  DEBT_CONSOLIDATION                60
# 4                 0      10600  DEBT_CONSOLIDATION                36
#
#    loan_int_rate  loan_percent_income  cb_person_cred_hist_length  \
# 0          17.32               0.2476                          32
# 1          11.59               1.5100                          22
# 2          17.32               0.6504                          20
# 3          10.51               0.2200                          18
# 4          17.24               0.2899                          51
#
#    credit_score previous_loan_defaults_on_file  loan_status application_date
# 0           713                             No            0       2023-06-15
# 1           845                             No            0       2025-12-26
# 2           755                             No            0       2024-11-01
# 3           752                             No            0       2022-08-05
# 4           655                             No            0       2024-03-31

# %%
data.describe()
# Out:
#          person_age  person_income  person_emp_exp  has_help_debt  \
# count  45000.000000   45000.000000    45000.000000   45000.000000
# mean      45.203067   69671.052511        7.902822       0.261289
# std       12.964998   41039.779524        5.074021       0.439342
# min       19.000000   20000.000000        0.000000       0.000000
# 25%       35.000000   41341.500000        4.000000       0.000000
# 50%       43.000000   60041.500000        7.000000       0.000000
# 75%       53.000000   86726.250000       11.000000       1.000000
# max       75.000000  450000.000000       42.000000       1.000000
#
#        help_debt_amount     loan_amnt  loan_term_months  loan_int_rate  \
# count      45000.000000  45000.000000      45000.000000   45000.000000
# mean        5624.383333  19898.511111         44.193067      13.868166
# std        11867.780144  13531.481566         16.951981       3.482621
# min            0.000000   2000.000000         12.000000       5.500000
# 25%            0.000000  10400.000000         36.000000      11.490000
# 50%            0.000000  16200.000000         36.000000      13.860000
# 75%         6552.000000  25300.000000         60.000000      16.230000
# max       120000.000000  75000.000000         84.000000      25.000000
#
#        loan_percent_income  cb_person_cred_hist_length  credit_score  \
# count         45000.000000                45000.000000  45000.000000
# mean              0.380636                   25.213200    750.014200
# std               0.358898                   13.041812    159.552923
# min               0.007500                    0.000000     58.000000
# 25%               0.152300                   15.000000    642.000000
# 50%               0.271000                   23.000000    751.000000
# 75%               0.479200                   33.000000    859.000000
# max               3.750000                   57.000000   1200.000000
#
#         loan_status
# count  45000.000000
# mean       0.523067
# std        0.499473
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %%
#clearing whitespace 
for col in  ['person_gender', 'person_education', 'person_home_ownership', 'loan_intent', 'previous_loan_defaults_on_file']:
    data[col] = data[col].astype(str).str.strip()

#changing column names to make it easierr to find later
data.rename(columns={'cb_person_cred_hist_length': 'credit_history_length'}, inplace=True)

# %% [markdown]
# ### Pruning the dataset before filling in nulls:

# %%
# taking care of duplicate applications
print("Duplicate rows: ", data.duplicated().sum())
data = data.drop_duplicates()
# Out:
# Duplicate rows:  0

# %%
# Datatype validation

# integers first:
int_cols = ['person_age','person_emp_exp','loan_amnt','loan_status','credit_history_length','has_help_debt','help_debt_amount','credit_score','loan_term_months']

for col in int_cols:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# floats
float_cols = ['person_income','loan_int_rate','loan_percent_income']

for col in float_cols:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# dates
date_cols = ['application_date']

for col in date_cols:
    data[col] = pd.to_datetime(data[col], errors='coerce')

# categories
cat_cols = ['person_gender','person_education','person_state','person_emp_status','person_home_ownership','loan_intent','previous_loan_defaults_on_file']

for col in cat_cols:
    data[col] = (data[col].astype(str).str.strip().str.upper())

# %%
# verify datatypes
print(data.dtypes)
# Out:
# person_age                                 int64
# person_gender                             object
# person_education                          object
# person_state                              object
# person_income                              int64
# person_emp_status                         object
# person_emp_exp                             int64
# person_home_ownership                     object
# has_help_debt                              int64
# help_debt_amount                           int64
# loan_amnt                                  int64
# loan_intent                               object
# loan_term_months                           int64
# loan_int_rate                            float64
# loan_percent_income                      float64
# credit_history_length                      int64
# credit_score                               int64
# previous_loan_defaults_on_file            object
# loan_status                                int64
# application_date                  datetime64[ns]
# dtype: object

# %%
# null check after conversion
print(data.isnull().sum())
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_state                      0
# person_income                     0
# person_emp_status                 0
# person_emp_exp                    0
# person_home_ownership             0
# has_help_debt                     0
# help_debt_amount                  0
# loan_amnt                         0
# loan_intent                       0
# loan_term_months                  0
# loan_int_rate                     0
# loan_percent_income               0
# credit_history_length             0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# application_date                  0
# dtype: int64

# %%
# drop only required nulls
ignore = ['loan_percent_income', 'loan_int_rate', 'loan_status', 'previous_loan_defaults_on_file']
included_cols = [col for col in data.columns if col not in ignore]
data.dropna(subset=included_cols, inplace=True)

# %%
#Invalid / Zero value loan requests
data = data[data['loan_amnt'] > 0]

# %%
#repayment term
data = data[data['loan_term_months'] > 0]

# %%
#credit score check acc to australian standards
data = data[(data['credit_score'] >0 ) & (data['credit_score'] < 1200)]

# %%
#credit history check
data = data[(data['credit_history_length']>=0) & (data['credit_history_length'] < 60) ]

# %%
#realistic age check
data = data[(data['person_age']>=18) & (data['person_age']<=100)]

# %%
#Invalid / Zero value income
data = data[(data['person_income'] > 0)]

# %%
# realistic experience check
data = data[(data['person_emp_exp']>=0) & (data['person_emp_exp']<=70)]

# %%
data = data[(data['help_debt_amount']>=0) & (data['help_debt_amount']<=150000)]

# %%
# allowed category values

valid_gender = ['MALE','FEMALE','NON-BINARY']

valid_education = ['HIGH SCHOOL','CERTIFICATE/DIPLOMA','BACHELOR','POSTGRADUATE','DOCTORATE']

valid_states = ['NSW','VIC','QLD','WA','SA','TAS','ACT','NT']

valid_emp_status = ['FULL-TIME','PART-TIME','SELF-EMPLOYED','CASUAL','UNEMPLOYED']

valid_home_ownership = ['RENT','MORTGAGE','OWN','FAMILY','OTHER']

valid_loan_intent = ['VEHICLE','DEBT_CONSOLIDATION','HOME_IMPROVEMENT','MEDICAL','HOLIDAY','EDUCATION','PERSONAL']

valid_defaults = ['YES','NO']

# %%
# filter out invalid categories
data = data[data['person_gender'].isin(valid_gender)]

# %%
data = data[data['person_education'].isin(valid_education)]

# %%
data = data[data['person_state'].isin(valid_states)]

# %%
data = data[data['person_emp_status'].isin(valid_emp_status)]

# %%
data = data[data['person_home_ownership'].isin(valid_home_ownership)]

# %%
data = data[data['loan_intent'].isin(valid_loan_intent)]

# %%
data = data[data['previous_loan_defaults_on_file'].isin(valid_defaults)]

# %%
data.shape
# Out:
# (44888, 20)

# %% [markdown]
# ### Checking Nulls and filling data

# %%
data.isnull().sum()
#no null values because the dataset used is a synthetic one.
#still I've added checks for filling in null values
# Out:
# person_age                        0
# person_gender                     0
# person_education                  0
# person_state                      0
# person_income                     0
# person_emp_status                 0
# person_emp_exp                    0
# person_home_ownership             0
# has_help_debt                     0
# help_debt_amount                  0
# loan_amnt                         0
# loan_intent                       0
# loan_term_months                  0
# loan_int_rate                     0
# loan_percent_income               0
# credit_history_length             0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# application_date                  0
# dtype: int64

# %%
#Interest rate check
if data['loan_int_rate'].isnull().sum() > 0:
    data['loan_int_rate'].fillna((data.groupby(['loan_intent', 'home_ownership', ])['loan_int_rate'].median()), inplace=True)
data = data[(data['loan_int_rate'] > 5.0) & (data['loan_int_rate'] <30.0)]

# %%
#Loan status check (0: rejected 1: accepted 2: pending)
if data['loan_status'].isnull().sum() > 0:
    data['loan_status'].fillna(2, inplace=True)
data = data[data['loan_status'].isin([0,1,2])]

# %%
data.head(5)
# Out:
#    person_age person_gender     person_education person_state  person_income  \
# 0          50        FEMALE            DOCTORATE           WA          53716
# 1          41          MALE  CERTIFICATE/DIPLOMA          VIC          20000
# 2          40          MALE         POSTGRADUATE           SA          34133
# 3          40        FEMALE             BACHELOR           WA          71808
# 4          71        FEMALE             BACHELOR          VIC          36560
#
#   person_emp_status  person_emp_exp person_home_ownership  has_help_debt  \
# 0        UNEMPLOYED               4                  RENT              0
# 1         FULL-TIME               9                  RENT              0
# 2            CASUAL               8              MORTGAGE              0
# 3         FULL-TIME               2                   OWN              1
# 4         FULL-TIME              10                  RENT              0
#
#    help_debt_amount  loan_amnt         loan_intent  loan_term_months  \
# 0                 0      13300    HOME_IMPROVEMENT                60
# 1                 0      30200  DEBT_CONSOLIDATION                36
# 2                 0      22200            PERSONAL                36
# 3             19626      15800  DEBT_CONSOLIDATION                60
# 4                 0      10600  DEBT_CONSOLIDATION                36
#
#    loan_int_rate  loan_percent_income  credit_history_length  credit_score  \
# 0          17.32               0.2476                     32           713
# 1          11.59               1.5100                     22           845
# 2          17.32               0.6504                     20           755
# 3          10.51               0.2200                     18           752
# 4          17.24               0.2899                     51           655
#
#   previous_loan_defaults_on_file  loan_status application_date
# 0                             NO            0       2023-06-15
# 1                             NO            0       2025-12-26
# 2                             NO            0       2024-11-01
# 3                             NO            0       2022-08-05
# 4                             NO            0       2024-03-31

# %% [markdown]
# ### Derived values

# %%
#Loan to income ratio recalculation since we dropped some values
data['loan_percent_income'] = data['loan_amnt'] / data['person_income'].round(2)

# %%
#Income tiers
data['income_tier'] = pd.cut(data['person_income'], bins = [0, 50000, 100000, 200000, 500000], labels=['LOW', 'MIDDLE', 'UPPER-MIDDLE', 'HIGH'])

# %%
# income to loan ratio bands
data['dti_band'] = pd.cut(data['loan_percent_income'], bins = [0, 0.15, 0.35, 1.0, 5.0], labels=['LOW', 'MIDDLE', 'HIGH', 'VERY HIGH'])

# %%
# age groups
data['age_group'] = pd.cut(data['person_age'], bins = [18, 25, 35, 50, 100], labels=['YOUNG ADULT', 'ADULT', 'MIDDLE-AGED', 'SENIOR'])

# %%
# credit score categories
data['credit_score_category'] = pd.cut(data['credit_score'], bins = [0, 460, 661, 735, 853, 1200], labels=['BELOW AVG', 'AVG', 'GOOD', 'VERY GOOD', 'EXCELLENT'])

# %%
#leanding risk flags

#has existing help debt + low income (error somewhere)
#data['flag_help_debt'] = ((data['has_help_debt'] == 1) & (data['income_tier'] == 'LOW')).astype(int) 

#young applicant + large loan request
data['flag_young_high_loan'] = ((data['person_age'] <25) & (data['loan_amnt'] > 50000)).astype(int)

# %%
#risk flags contd

#very high loan request compared to income
data['flag_income_loan_mismatch'] = (data['loan_percent_income'] > 0.5).astype(int)

# Employment experience impossible given age
data['flag_impossible_exp'] = (data['person_emp_exp'] >= (data['person_age'] - 16)).astype(int)

# Credit history longer than working life
data['flag_impossible_credit_history'] = (data['credit_history_length'] >= data['person_age'] - 16).astype(int)

# Suspiciously round high income (common fraudulent entries)
data['flag_round_income'] = ((data['person_income'] % 10000 == 0) & (data['person_income'] > 100000)).astype(int)

#previously defaulted but approved now
data['flag_default'] = ((data['previous_loan_defaults_on_file']=='YES') & (data['loan_status']== 1)).astype(int)

#unemployed yet approved for loan
data['flag_unemployment'] = ((data['person_emp_status']=='UNEMPLOYED') & (data['loan_status']== 1)).astype(int)

flag_cols = [
    'flag_income_loan_mismatch',
    'flag_impossible_exp',
    'flag_impossible_credit_history',
    'flag_round_income',
    'flag_unemployment',
    'flag_default'
]

data['risk_flag_count'] = data[flag_cols].sum(axis=1)

# %%
#sort by loan application date
data = data.sort_values('application_date').reset_index(drop=True)

# %%
#id
data.insert(0, 'id', range(100000, len(data) + 100000))
data['id'] = ('APP' + data['id'].astype(str))

# %%
data.head(5)
# Out:
#           id  person_age person_gender     person_education person_state  \
# 0  APP100000          39          MALE          HIGH SCHOOL          QLD
# 1  APP100001          25          MALE  CERTIFICATE/DIPLOMA           SA
# 2  APP100002          45        FEMALE  CERTIFICATE/DIPLOMA           WA
# 3  APP100003          38          MALE             BACHELOR          VIC
# 4  APP100004          75          MALE             BACHELOR          NSW
#
#    person_income person_emp_status  person_emp_exp person_home_ownership  \
# 0          62994         FULL-TIME               9                   OWN
# 1          77107         FULL-TIME               5              MORTGAGE
# 2          30752         PART-TIME              21                  RENT
# 3          84232         FULL-TIME               5                FAMILY
# 4         141352         PART-TIME               1              MORTGAGE
#
#    has_help_debt  ...    age_group  credit_score_category  \
# 0              0  ...  MIDDLE-AGED              VERY GOOD
# 1              0  ...  YOUNG ADULT                   GOOD
# 2              0  ...  MIDDLE-AGED                   GOOD
# 3              1  ...  MIDDLE-AGED              EXCELLENT
# 4              0  ...       SENIOR              VERY GOOD
#
#   flag_young_high_loan  flag_income_loan_mismatch  flag_impossible_exp  \
# 0                    0                          0                    0
# 1                    0                          0                    0
# 2                    0                          1                    0
# 3                    0                          1                    0
# 4                    0                          0                    0
#
#    flag_impossible_credit_history  flag_round_income  flag_default  \
# 0                               0                  0             0
# 1                               0                  0             0
# 2                               0                  0             0
# 3                               0                  0             0
# 4                               0                  0             0
#
#   flag_unemployment  risk_flag_count
# 0                 0                0
# 1                 0                0
# 2                 0                1
# 3                 0                1
# 4                 0                0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Final look over

# %%
data.describe()
# Out:
#          person_age  person_income  person_emp_exp  has_help_debt  \
# count  44888.000000   44888.000000    44888.000000   44888.000000
# mean      45.207828   69673.065920        7.901332       0.261317
# min       19.000000   20000.000000        0.000000       0.000000
# 25%       35.000000   41345.000000        4.000000       0.000000
# 50%       43.000000   60042.500000        7.000000       0.000000
# 75%       53.000000   86725.250000       11.000000       1.000000
# max       75.000000  450000.000000       42.000000       1.000000
# std       12.967694   41047.758576        5.072632       0.439357
#
#        help_debt_amount     loan_amnt  loan_term_months  loan_int_rate  \
# count      44888.000000  44888.000000      44888.000000   44888.000000
# mean        5624.894382  19899.095527         44.190251      13.867710
# min            0.000000   2000.000000         12.000000       5.500000
# 25%            0.000000  10400.000000         36.000000      11.490000
# 50%            0.000000  16200.000000         36.000000      13.860000
# 75%         6552.000000  25300.000000         60.000000      16.230000
# max       120000.000000  75000.000000         84.000000      25.000000
# std        11863.580765  13530.712047         16.951138       3.482739
#
#        loan_percent_income  credit_history_length  ...   loan_status  \
# count         44888.000000           44888.000000  ...  44888.000000
# mean              0.380650              25.217965  ...      0.522567
# min               0.007456               0.000000  ...      0.000000
# 25%               0.152275              15.000000  ...      0.000000
# 50%               0.271006              23.000000  ...      1.000000
# 75%               0.479068              33.000000  ...      1.000000
# max               3.750000              57.000000  ...      1.000000
# std               0.358906              13.044230  ...      0.499496
#
#                     application_date flag_young_high_loan  \
# count                          44888         44888.000000
# mean   2023-12-27 17:37:09.549099776             0.000847
# min              2022-01-01 00:00:00             0.000000
# 25%              2022-12-27 00:00:00             0.000000
# 50%              2023-12-25 00:00:00             0.000000
# 75%              2024-12-28 00:00:00             0.000000
# max              2025-12-31 00:00:00             1.000000
# std                              NaN             0.029084
#
#        flag_income_loan_mismatch  flag_impossible_exp  \
# count               44888.000000              44888.0
# mean                    0.233826                  0.0
# min                     0.000000                  0.0
# 25%                     0.000000                  0.0
# 50%                     0.000000                  0.0
# 75%                     0.000000                  0.0
# max                     1.000000                  0.0
# std                     0.423268                  0.0
#
#        flag_impossible_credit_history  flag_round_income  flag_default  \
# count                         44888.0       44888.000000  44888.000000
# mean                              0.0           0.000045      0.059927
# min                               0.0           0.000000      0.000000
# 25%                               0.0           0.000000      0.000000
# 50%                               0.0           0.000000      0.000000
# 75%                               0.0           0.000000      0.000000
# max                               0.0           1.000000      1.000000
# std                               0.0           0.006675      0.237354
#
#        flag_unemployment  risk_flag_count
# count       44888.000000     44888.000000
# mean            0.013211         0.307009
# min             0.000000         0.000000
# 25%             0.000000         0.000000
# 50%             0.000000         0.000000
# 75%             0.000000         1.000000
# max             1.000000         3.000000
# std             0.114177         0.475340
#
# [8 rows x 21 columns]

# %%
data['loan_status'].value_counts()
# Out:
# loan_status
# 1    23457
# 0    21431
# Name: count, dtype: int64

# %%
data.groupby('person_state')['loan_status'].mean()
# Out:
# person_state
# ACT    0.476312
# NSW    0.530878
# NT     0.504288
# QLD    0.526735
# SA     0.502207
# TAS    0.507479
# VIC    0.517536
# WA     0.528792
# Name: loan_status, dtype: float64

# %%
data.groupby('income_tier')['loan_status'].mean()
# Out:
# <ipython-input-48-df8975feb920>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   data.groupby('income_tier')['loan_status'].mean()
# income_tier
# LOW             0.396216
# MIDDLE          0.562285
# UPPER-MIDDLE    0.683423
# HIGH            0.725203
# Name: loan_status, dtype: float64

# %% [markdown]
# ### Final Validation

# %%
print(data.shape)
# Out:
# (44888, 33)

# %%
print(data.isnull().sum())
# Out:
# id                                0
# person_age                        0
# person_gender                     0
# person_education                  0
# person_state                      0
# person_income                     0
# person_emp_status                 0
# person_emp_exp                    0
# person_home_ownership             0
# has_help_debt                     0
# help_debt_amount                  0
# loan_amnt                         0
# loan_intent                       0
# loan_term_months                  0
# loan_int_rate                     0
# loan_percent_income               0
# credit_history_length             0
# credit_score                      0
# previous_loan_defaults_on_file    0
# loan_status                       0
# application_date                  0
# income_tier                       0
# dti_band                          0
# age_group                         0
# credit_score_category             0
# flag_young_high_loan              0
# flag_income_loan_mismatch         0
# flag_impossible_exp               0
# flag_impossible_credit_history    0
# flag_round_income                 0
# flag_default                      0
# flag_unemployment                 0
# risk_flag_count                   0
# dtype: int64

# %%
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Exporting CSVs

# %%
loan_details = data[['id', 'application_date', 'loan_amnt', 'loan_int_rate', 'loan_percent_income', 'loan_term_months', 'loan_status', 'dti_band']]

# %%
applicant_details = data[
    [
        'id',
        'person_age',
        'person_gender',
        'person_education',
        'person_income',
        'income_tier',
        'person_emp_status',
        'person_emp_exp',
        'person_home_ownership',
        'person_state'
    ]
]

# %%
credit_details = data[
    [
        'id',
        'credit_score',
        'credit_history_length',
        'previous_loan_defaults_on_file',
        'has_help_debt',
        'help_debt_amount'
    ]
]

# %%
risk_flags = data[
    [
        'id', 
        'flag_income_loan_mismatch',
        'flag_impossible_exp',
        'flag_impossible_credit_history', 
        'flag_round_income', 
        'flag_default', 
        'flag_unemployment',  
        'flag_impossible_exp',
        'flag_unemployment',
        'risk_flag_count',
        'flag_young_high_loan' 
    ]
]

# %% [raw]
# loan_details.to_csv('loan_details.csv', index=False)
#
# applicant_details.to_csv('applicant_details.csv', index=False)
#
# credit_details.to_csv('credit_details.csv', index=False)
#
# risk_flags.to_csv('risk_flags.csv', index=False)

# %% [markdown]
# ### Created CSV checks

# %% [markdown]
# # Modeling

# %% [markdown]
# ## Selecting features for modelling

# %%
data.keys()
# Out:
# Index(['id', 'person_age', 'person_gender', 'person_education', 'person_state',
#        'person_income', 'person_emp_status', 'person_emp_exp',
#        'person_home_ownership', 'has_help_debt', 'help_debt_amount',
#        'loan_amnt', 'loan_intent', 'loan_term_months', 'loan_int_rate',
#        'loan_percent_income', 'credit_history_length', 'credit_score',
#        'previous_loan_defaults_on_file', 'loan_status', 'application_date',
#        'income_tier', 'dti_band', 'age_group', 'credit_score_category',
#        'flag_young_high_loan', 'flag_income_loan_mismatch',
#        'flag_impossible_exp', 'flag_impossible_credit_history',
#        'flag_round_income', 'flag_default', 'flag_unemployment',
#        'risk_flag_count'],
#       dtype='object')

# %%
model_col = ['person_age', 'person_gender', 'person_education', 'person_state',
       'person_income', 'person_emp_status', 'person_emp_exp',
       'person_home_ownership','help_debt_amount',
       'loan_amnt', 'loan_intent', 'loan_term_months', 'loan_int_rate',
       'loan_percent_income', 'credit_history_length', 'credit_score',
       'previous_loan_defaults_on_file', 'loan_status','flag_income_loan_mismatch', 'flag_young_high_loan'
        ]
datam = data[model_col].copy()
datam.to_csv('modelling_data.csv', index=False)
